# %% [markdown]
# # Genre Surf - music genre classification V#2

# %% [markdown]
# ## 1. Dataset download

# %%
# kaggle API 인증
import os
os.environ['KAGGLE_USERNAME'] = "lindocachete"
os.environ['KAGGLE_KEY'] = "e23976ec213f99d8ef61e215e881c977"

# %%
# kaggle 안의 GTZAN 활용을 위해 kaggle 설치
# !pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /opt/anaconda3/lib/python3.9/site-packages (1.5.12)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from kaggle) (4.64.1)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.9/site-packages (from kaggle) (1.26.11)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/lib/python3.9/site-packages (from kaggle) (2.8.2)
# Requirement already satisfied: python-slugify in /opt/anaconda3/lib/python3.9/site-packages (from kaggle) (7.0.0)
# Requirement already satisfied: six>=1.10 in /opt/anaconda3/lib/python3.9/site-packages (from kaggle) (1.16.0)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.9/site-packages (from kaggle) (2.28.1)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.9/site-packages (from kaggle) (2022.9.24)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/anaconda3/lib/python3.9/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests->kaggle) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests->kaggle) (2.0.4)

# %%
# GTZAN의 음악 장르 데이터셋 다운로드 받기
# !kaggle datasets download -d andradaolteanu/gtzan-dataset-music-genre-classification
# Out:
# Downloading gtzan-dataset-music-genre-classification.zip to /Users/taehwan/Monte/genre-surf/music-classification
# 100%|██████████████████████████████████████| 1.21G/1.21G [01:56<00:00, 11.2MB/s]
# 100%|██████████████████████████████████████| 1.21G/1.21G [01:56<00:00, 11.1MB/s]

# %%
# 데이터셋 압축 해제하기
# !unzip -q gtzan-dataset-music-genre-classification.zip

# %%
# 오디오 분석 라이브러리 설치
# !pip install librosa
# Out:
# Requirement already satisfied: librosa in /opt/anaconda3/lib/python3.9/site-packages (0.9.2)
# Requirement already satisfied: decorator>=4.0.10 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (5.1.1)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (21.3)
# Requirement already satisfied: audioread>=2.1.9 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (3.0.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: numba>=0.45.1 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (0.55.1)
# Requirement already satisfied: soundfile>=0.10.2 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (0.11.0)
# Requirement already satisfied: pooch>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.2.0)
# Requirement already satisfied: resampy>=0.2.2 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (0.4.2)
# Requirement already satisfied: scipy>=1.2.0 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.9.1)
# Requirement already satisfied: numpy>=1.17.0 in /opt/anaconda3/lib/python3.9/site-packages (from librosa) (1.21.6)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (63.4.1)
# Requirement already satisfied: llvmlite<0.39,>=0.38.0rc1 in /opt/anaconda3/lib/python3.9/site-packages (from numba>=0.45.1->librosa) (0.38.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/anaconda3/lib/python3.9/site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: appdirs>=1.3.0 in /opt/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/lib/python3.9/site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.19.1->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in /opt/anaconda3/lib/python3.9/site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.9/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.11)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/anaconda3/lib/python3.9/site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.0.4)

# %% [markdown]
# ## 2. Upload audio file

# %%
# import
import librosa
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
import sklearn

# %%
# 파일명 입력(Data 폴더와 같은 폴더에 존재)
filename = 'genres_original/pop/pop.00015.wav'

# y: 시간에 따른 파형 그래프, 소리 및 신호가 떨리는 세기 및 진폭 / Waveform
# sr: 1초당 샘플의 개수(Hz) / Sampling Rate
y, sr = librosa.load('Data/' + filename)

print(y)
print(len(y))
print('Sampling rate: ', sr)
print('Audio length: ', (len(y) / sr))
# Out:
# [ 0.01809692 -0.00827026  0.02719116 ... -0.11218262 -0.03579712
#  -0.00421143]
# 661504
# Sampling rate:  22050
# Audio length:  30.00018140589569

# %%
# 오디오 파일 및 스펙트럼 확인
import IPython.display as ipd

ipd.Audio(y, rate = sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## 3. Extract audio features
# - chroma frequencies
# - RMS
# - spectral centroid
# - spectral bandwidth
# - spectral rolloff
# - zero crossing rate
# - harmonic components
# - percussive components
# - tempo
# - MFCCs

# %%
# 오디오 파일 분석 결과 사전(dict)
audioFeatures = dict()

# %%
# 오디오 파일 내의 음높이 분포도
chroma = librosa.feature.chroma_stft(y = y, sr = sr)
audioFeatures['chroma_stft_mean'] = chroma.mean()
audioFeatures['chroma_stft_var'] = chroma.var()
# audioFeatures.append(chroma.mean())
# audioFeatures.append(chroma.var())

# 결과 확인
print('Audio feature values: ', audioFeatures)

plt.figure(figsize = (16,6))
librosa.display.specshow(chroma, y_axis = 'chroma',x_axis = 'time')
plt.show()
# Out:
# Audio feature values:  {'chroma_stft_mean': 0.38674167, 'chroma_stft_var': 0.08903726}

# %%
# 오디오 파일의 시간에 따른 음파 변화 분석
rms = librosa.feature.rms(y = y)
audioFeatures['rms_mean'] = rms.mean()
audioFeatures['rms_var'] = rms.var()

# 결과 확인
print('Audio feature values: ', audioFeatures)

plt.figure(figsize = (16,6))
times = librosa.times_like(rms)
plt.plot(times, rms[0], label = 'rms', color = 'steelblue')
plt.legend()
plt.show()
# Out:
# Audio feature values:  {'chroma_stft_mean': 0.38674167, 'chroma_stft_var': 0.08903726, 'rms_mean': 0.1960698, 'rms_var': 0.006240664}

# %%
# 오디오 파일의 무게중심 분석
spec_cent = librosa.feature.spectral_centroid(y = y, sr = sr)
audioFeatures['spectral_centroid_mean'] = spec_cent.mean()
audioFeatures['spectral_centroid_var'] = spec_cent.var()

# 오디오 파일의 주파수 대역폭 분석
spec_bw = librosa.feature.spectral_bandwidth(y = y, sr = sr)
audioFeatures['spectral_bandwidth_mean'] = spec_bw.mean()
audioFeatures['spectral_bandwidth_var'] = spec_bw.var()

# 오디오 파일의 최상/최하 주파수의 감쇠현상 분석
spec_rolloff = librosa.feature.spectral_rolloff(y = y, sr = sr)
audioFeatures['rolloff_mean'] = spec_rolloff.mean()
audioFeatures['rolloff_var'] = spec_rolloff.var()

# 결과 확인
print('Audio feature values: ', audioFeatures)

plt.figure(figsize = (16,6))
times = librosa.times_like(spec_cent)
plt.plot(times, spec_cent.T, label = 'Spectral centroid', color = 'steelblue')
plt.plot(times, spec_bw.T, label = 'Spectral bandwidth', color = 'paleturquoise')
plt.plot(times, spec_rolloff.T, label = 'Spectral rolloff', color = 'lightsteelblue')
plt.legend()
plt.show()
# Out:
# Audio feature values:  {'chroma_stft_mean': 0.38674167, 'chroma_stft_var': 0.08903726, 'rms_mean': 0.1960698, 'rms_var': 0.006240664, 'spectral_centroid_mean': 3207.6174705599383, 'spectral_centroid_var': 842189.7134517938, 'spectral_bandwidth_mean': 3125.923874185513, 'spectral_bandwidth_var': 128144.25399151548, 'rolloff_mean': 7020.323829031323, 'rolloff_var': 2435910.520629917}

# %%
# 오디오 파일의 볼륨 영교차 분석
zeroCrossingRate = librosa.feature.zero_crossing_rate(y)
audioFeatures['zero_crossing_rate_mean'] = zeroCrossingRate.mean()
audioFeatures['zero_crossing_rate_var'] = zeroCrossingRate.var()

# 결과 확인
print('Audio feature values: ', audioFeatures)
# Out:
# Audio feature values:  {'chroma_stft_mean': 0.38674167, 'chroma_stft_var': 0.08903726, 'rms_mean': 0.1960698, 'rms_var': 0.006240664, 'spectral_centroid_mean': 3207.6174705599383, 'spectral_centroid_var': 842189.7134517938, 'spectral_bandwidth_mean': 3125.923874185513, 'spectral_bandwidth_var': 128144.25399151548, 'rolloff_mean': 7020.323829031323, 'rolloff_var': 2435910.520629917, 'zero_crossing_rate_mean': 0.1415838136842614, 'zero_crossing_rate_var': 0.006964838291186281}

# %%
# 오디오 파일의 하모닉 및 고조파류(수평적 요소), 타악기류(수직적 요소) 사운드 분석
harmony, perceptr = librosa.effects.hpss(y, margin = 3.0)
audioFeatures['harmony_mean'] = harmony.mean()
audioFeatures['harmony_var'] = harmony.var()
audioFeatures['perceptr_mean'] = perceptr.mean()
audioFeatures['perceptr_var'] = perceptr.var()

# 결과 확인
print('Audio feature values: ', audioFeatures)
# Out:
# Audio feature values:  {'chroma_stft_mean': 0.38674167, 'chroma_stft_var': 0.08903726, 'rms_mean': 0.1960698, 'rms_var': 0.006240664, 'spectral_centroid_mean': 3207.6174705599383, 'spectral_centroid_var': 842189.7134517938, 'spectral_bandwidth_mean': 3125.923874185513, 'spectral_bandwidth_var': 128144.25399151548, 'rolloff_mean': 7020.323829031323, 'rolloff_var': 2435910.520629917, 'zero_crossing_rate_mean': 0.1415838136842614, 'zero_crossing_rate_var': 0.006964838291186281, 'harmony_mean': 5.9808065e-07, 'harmony_var': 0.006761803, 'perceptr_mean': -1.7157028e-05, 'perceptr_var': 0.0037146257}

# %%
# 오디오 파일의 템포(BPM) 분석
tempo,_ = librosa.beat.beat_track(y = y, sr = sr)
audioFeatures['tempo'] = tempo

# 결과 확인
print('Audio feature values: ', audioFeatures)
# Out:
# Audio feature values:  {'chroma_stft_mean': 0.38674167, 'chroma_stft_var': 0.08903726, 'rms_mean': 0.1960698, 'rms_var': 0.006240664, 'spectral_centroid_mean': 3207.6174705599383, 'spectral_centroid_var': 842189.7134517938, 'spectral_bandwidth_mean': 3125.923874185513, 'spectral_bandwidth_var': 128144.25399151548, 'rolloff_mean': 7020.323829031323, 'rolloff_var': 2435910.520629917, 'zero_crossing_rate_mean': 0.1415838136842614, 'zero_crossing_rate_var': 0.006964838291186281, 'harmony_mean': 5.9808065e-07, 'harmony_var': 0.006761803, 'perceptr_mean': -1.7157028e-05, 'perceptr_var': 0.0037146257, 'tempo': 103.359375}

# %%
# 오디오 파일의 MFCCs 및 음색 분석
mfcc = librosa.feature.mfcc(y = y, sr = sr)

# MFCC 추출이 정상적으로 되었는지 확인, 배열 20개가 나오면 정상
print(len(mfcc))

for i in range(0, len(mfcc)):
    mfcc_mean = 'mfcc' + str(i + 1) + '_mean'
    mfcc_var = 'mfcc' + str(i + 1) + '_var'
    audioFeatures[mfcc_mean] = mfcc[i].mean()
    audioFeatures[mfcc_var] = mfcc[i].var()
    
# 결과 확인
print('Audio feature values: ', audioFeatures)

# label은 학습에 사용하지 않으므로 비워둔다.
# Out:
# 20
# Audio feature values:  {'chroma_stft_mean': 0.38674167, 'chroma_stft_var': 0.08903726, 'rms_mean': 0.1960698, 'rms_var': 0.006240664, 'spectral_centroid_mean': 3207.6174705599383, 'spectral_centroid_var': 842189.7134517938, 'spectral_bandwidth_mean': 3125.923874185513, 'spectral_bandwidth_var': 128144.25399151548, 'rolloff_mean': 7020.323829031323, 'rolloff_var': 2435910.520629917, 'zero_crossing_rate_mean': 0.1415838136842614, 'zero_crossing_rate_var': 0.006964838291186281, 'harmony_mean': 5.9808065e-07, 'harmony_var': 0.006761803, 'perceptr_mean': -1.7157028e-05, 'perceptr_var': 0.0037146257, 'tempo': 103.359375, 'mfcc1_mean': -45.799076, 'mfcc1_var': 4353.2686, 'mfcc2_mean': 65.26662, 'mfcc2_var': 578.0732, 'mfcc3_mean': 12.929744, 'mfcc3_var': 453.08197, 'mfcc4_mean': 14.511338, 'mfcc4_var': 261.66364, 'mfcc5_mean': 7.0173607, 'mfcc5_var': 113.296776, 'mfcc6_mean': 4.410114, 'mfcc6_var': 185.95381, 'mfcc7_mean': 6.6034317, 'mfcc7_var': 150.88269, 'mfcc8_mean': 3.2921526, 'mfcc8_var': 86.70116, 'mfcc9_mean': 7.733731, 'mfcc9_var': 77.044556, 'mfcc10_mean': 4.0534663, 'mfcc10_var': 77.271996, 'mfcc11_mean': 3.658238, 'mfcc11_var': 50.40797, 'mfcc12_mean': 2.6003695, 'mfcc12_var': 59.324596, 'mfcc13_mean': 4.0506835, 'mfcc13_var': 57.965603, 'mfcc14_mean': 2.3965278, 'mfcc14_var': 59.17083, 'mfcc15_mean': 1.7817205, 'mfcc15_var': 42.219734, 'mfcc16_mean': -2.3767538, 'mfcc16_var': 41.812218, 'mfcc17_mean': -1.3439593, 'mfcc17_var': 54.70814, 'mfcc18_mean': -2.8729863, 'mfcc18_var': 78.7171, 'mfcc19_mean': -0.8414323, 'mfcc19_var': 74.265045, 'mfcc20_mean': -2.5950575, 'mfcc20_var': 64.92086}

# %% [markdown]
# ## Training model

# %%
# import
import pandas as pd
import numpy as np
import seaborn as sns
from xgboost import XGBClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
# 학습할 데이터 가져오기
data = pd.read_csv('Data/features_3_sec.csv')

# 학습에 필요하지 않은 데이터 제외
# 파일 길이는 모두 동일하여 학습에 의미가 없다 판단하여 제외
data = data.drop('filename', axis = 'columns')
data = data.drop('length', axis = 'columns')
data.head()
# Out:
#    chroma_stft_mean  chroma_stft_var  rms_mean   rms_var  \
# 0          0.335406         0.091048  0.130405  0.003521
# 1          0.343065         0.086147  0.112699  0.001450
# 2          0.346815         0.092243  0.132003  0.004620
# 3          0.363639         0.086856  0.132565  0.002448
# 4          0.335579         0.088129  0.143289  0.001701
#
#    spectral_centroid_mean  spectral_centroid_var  spectral_bandwidth_mean  \
# 0             1773.065032          167541.630869              1972.744388
# 1             1816.693777           90525.690866              2010.051501
# 2             1788.539719          111407.437613              2084.565132
# 3             1655.289045          111952.284517              1960.039988
# 4             1630.656199           79667.267654              1948.503884
#
#    spectral_bandwidth_var  rolloff_mean   rolloff_var  ...  mfcc16_var  \
# 0           117335.771563   3714.560359  1.080790e+06  ...   39.687145
# 1            65671.875673   3869.682242  6.722448e+05  ...   64.748276
# 2            75124.921716   3997.639160  7.907127e+05  ...   67.336563
# 3            82913.639269   3568.300218  9.216524e+05  ...   47.739452
# 4            60204.020268   3469.992864  6.102111e+05  ...   30.336359
#
#    mfcc17_mean  mfcc17_var  mfcc18_mean  mfcc18_var  mfcc19_mean  mfcc19_var  \
# 0    -3.241280   36.488243     0.722209   38.099152    -5.050335   33.618073
# 1    -6.055294   40.677654     0.159015   51.264091    -2.837699   97.030830
# 2    -1.768610   28.348579     2.378768   45.717648    -1.938424   53.050835
# 3    -3.841155   28.337118     1.218588   34.770935    -3.580352   50.836224
# 4     0.664582   45.880913     1.689446   51.363583    -3.392489   26.738789
#
#    mfcc20_mean  mfcc20_var  label
# 0    -0.243027   43.771767  blues
# 1     5.784063   59.943081  blues
# 2     2.517375   33.105122  blues
# 3     3.630866   32.023678  blues
# 4     0.536961   29.146694  blues
#
# [5 rows x 58 columns]

# %%
# X(음악적 특성), Y(장르명 및 결과) 분할
X = data.loc[:, data.columns != 'label' ]
Y = data['label']

# 음악적 특성 값의 범위 정규화
cols = X.columns
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(X)

# 범위 정규화를 거친 데이터에 대한 데이터 프레임
X = pd.DataFrame(np_scaled, columns = cols)

# %%
# 훈련용 데이터, 평가용 데이터 분할
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=42)

# %%
# Extreme gradient boosting model - 분류에 뛰어난 예측 성능을 발휘한다 하여 활용
# 트리 기반 앙상블 학습 모델
xgb = XGBClassifier(n_estimators=1000, learning_rate=0.05)
xgb.fit(X_train, Y_train)

prediction = xgb.predict(X_test)

print('Accuracy: ', round(accuracy_score(Y_test, prediction) * 100, 5), '%')

# 오차 행렬 확인
confusion_matr = confusion_matrix(Y_test, prediction)
plt.figure(figsize = (16, 9))
sns.heatmap(confusion_matr, 
            cmap="Blues", 
            annot=True, 
            xticklabels = ["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"],
            yticklabels=["blues", "classical", "country", "disco", "hiphop", "jazz", "metal", "pop", "reggae", "rock"]
           );
plt.show()
# Out:
# Accuracy:  87.98799 %

# %%
# 사용자 입력 오디오 파일에 대한 장르 예측 및 결과 도출
newAudioDF = pd.DataFrame.from_dict([audioFeatures])
classifiedGenre = xgb.predict(newAudioDF)

# 결과 출력
print('Audio file: ', filename)
print('Genre classified: ', classifiedGenre[0])
# Out:
# Audio file:  genres_original/pop/pop.00015.wav
# Genre classified:  pop
